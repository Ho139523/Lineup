# %% [markdown]
# ### Importing required packages

# %%
# For times when you want a code not to be showed or shared via github with ohters
from google.colab import userdata
# It's added to add Data and .ipynb files or any file on drive which we want to have in colab directory.
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Git configurations

# %%
# !git config --global user.name "Ho139523"
# !git config --global user.email "answereeee4@gmail.com"

# %% [markdown]
# ### Importing token and passwords

# %%
token=userdata.get('token')
username='Ho139523'
repo='Lineup'
proj_folder='zeinab'

# %%
#!mkdir zeinab
#%cd zeinab
#!mkdir Data

# %%
# %cd /content/
# !git init
# !git remote add origin https://github.com/{username}/{repo}
# !git config core.sparsecheckout True
#!git sparse-checkout set {proj_folder}
# !git pull origin HEAD:main

# %%
text=open('FR.txt','r+')

# %%
#help(text)#.write('hello'))
text.read()
#text.writelines('hello')

# %%
def search_and_replace(file_path, search_word, replace_word):
    with open(file_path, 'r') as file:
      file_contents = file.read()

      updated_contents = file_contents.replace(search_word, replace_word)

    with open(file_path, 'w') as file:
      file.write(updated_contents)

# %%
search_and_replace('FR.txt', ' ---> ', ': (')

# %%
text=open('FR.txt', 'r')
text.read()

# %%
#%cd /content/{proj_folder}
# !cp /content/drive/MyDrive/Colab_Notebooks/Git.ipynb /content/
#%cd /content/{proj_folder}/Data
#!cp /content/drive/MyDrive/Data/Titanic/test.csv /content/{proj_folder}/Data
#!cp /content/drive/MyDrive/Data/Titanic/train.csv /content/{proj_folder}/Data

# %% [markdown]
# ### Adding files and folders to ignore files

# %%
# %cd /content/
# !touch .gitignore
# !echo "sample_data/" >> .gitignore
# !echo ".config/" >> .gitignore
# !echo ".git/" >> .gitignore
# !echo "drive/" >> .gitignore
# !echo ".ipynb_checkpoints/" >> .gitignore

# %%
# !git add --all
# !git commit -m "Initial commit and create the repo"
# !git remote set-url origin https://{token}@github.com/{username}/{repo}
# !git push origin HEAD:main
